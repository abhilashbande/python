# %% [markdown]
# # 18/06/2026
#
# **Day 1**

# %% [markdown]
# 18/06/2026 08:13AM
#    New Section 1 Page 1
#
#    New Section 1 Page 2
#
#    New Section 1 Page 3

# %% [markdown]
# # 19/06/2026
#
# **Day 2**

# %% [markdown]
# print('Hello word!')
# Hello word!
# Feature Of Python :
# 1. Simple and easy to learn :
# Python Syntax is just like an english language
# age=int(input('Emnter your age ='))
# if age>18:
#     print('It is applicable')
# else:
#     print('Not applicable')
# It is applicable
# 2. It is HIGH Level Language :
# Programmers do not to manage memory manually
#     LLL :
#         Binary 0/1
#         assimbly   ...AXDEL01
#     HLL:
#         Python --- interpreter
#         java --------- interpreter + compiler
#         ...... and so on
# name='Shiv'
# print(name)
# Shiv
# print(f'my name is {name}')
# my name is Shiv
# In [4]:
# In [6]:
# In [7]:
# In [8]:
#
# 3. Python --- interpreter PL:
# Python code execute line by line.
# Source code  ---> High Level Language (Python)
#     -
#     -
#     -
# Interpreter   ---> Language Translator
#     -
#     -
#     -
#   OutPut
# age=18
# print(age)
# if age>'18':
#     print('It is applicable')
# else:
#     print('Not applicable')
# 18
# In [13]:
#
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 age=18
#       2 print(age)
# ----> 3 if age>'18':
#       4     print('It is applicable')
#       5 else:
# TypeError: '>' not supported between instances of 'int' and 'str'
# Note : Each line execute sequentially Advantages: Easy debugging Faster development
# 4. It is Object Oriented Langauge and PPL :
# Python
# 1. PPL
# 2. OOPL
# 5. Portable langauge :
# Write once and run anywhere.
# without changing the source code
# Python ____SourceCode
# Linux    ---> ok
# macOS    ---> ok
# Windows  ---> ok
# 7. It is an Open Source :
# Python is Free
#     --> No License cost.
#     --> Python community support.
# 8. Extensive Library support :
#
# Python has thousand of Libraries.
# Data Analysis:
#     Numpy
#     Pandas
# Visualization :
#     Matplolib
#     seaborn
# Machine Learning :
#     Scikit_learn
# Deep Learning :
#     Tensorflow
#     PyTorch

# %% [markdown]
# # 20/06/2026
#
# **Day 3**

# %% [markdown]
# # Print function :
#     It is Python Built in Function used to display Output on the screen.
#
#     sep --->
#         Sep stands for separator .
#         It is used to define  what should be placed between multiple values inside the print() function , By default one space is placed .
#
#     end --->
#         It specifies what should be printed after the output is displayed.
#
#
#     Syntax :
#          print(*args, sep=' ', end='\n', file=None, flush=False)

# %%
print('Hello , worl!')

# %%
print(12,20,30,202,202,2,209,sep='\n')

# %%
print('Shiv',end='_')
print('pramod')
print('Omega')

# %%
#### sys.stdout by default>>> without print display the statement

# %%
import sys
sys.stdout.write('Shiv')

# %% [markdown]
# # What is a variable in python :
#     A variable is a name used to store data(Value) in Memory ,
#     It acts Like a container that hold the information which can be later in the programm.

# %%
name='Shivsharan'

# %%
print(Name)

# %%
pass=10

# %% [markdown]
# # Programming Type of Variable :
#     1. Static variable
#     2. Dynamic Variable
#
# #### Note :
#      Python  is  Dynamic Type of varible :

# %% [markdown]
# # python Types Of variable :
#     1. Local Variable
#     2. Global Variable

# %%
value=100   # Global Variable 
def my_variable():
    value=200   # Local Variable 
    print(value)

# %%
my_variable()

# %% [markdown]
# # Local variable :
#     inside the function
# # Global Variable:
#     outside the function

# %% [markdown]
# # Rules of Python Variable :

# %% [markdown]
# # 1. Albhabets (A-Z,a-z):
#     Variable can consist of Uppercase(A-Z) and Lowecase(a-z) letters.

# %%
NAME='Shivsharan'
print(NAME)

# %%
NAME

# %%
NAME=100

# %%
print(NAME)

# %%
print(name)

# %%
NaMe='Samiksha'
print(NaMe)

# %%
print(NAME)

# %% [markdown]
# # 2. AlphaNumeric :
#     Variable can Include number (Base10Value :0 to 9)  along with albhabets .It means the variable can Not start with number.

# %%
12Name='Shivram'

# %%
Name12='Shiv'
print(Name12)

# %%
A1B2C3='Rameshwar'
print(A1B2C3)

# %% [markdown]
# # 3. Special Character :
#     The Underscore character (like _ ) can be used in Variable name .

# %%
name_city ='Shiv and Pune'
print(name_city)

# %%
______=10
print(______)

# %%
___10=100
print(___10)

# %% [markdown]
# # 4. keyword restriction :
#     Variable Names can not be the same as Python keyword (reserved word)

# %%
import keyword
print(keyword.kwlist)

# %% [markdown]
# # 5. Case Sensitive :
#     Variable names in python are case Sensitive
#     e.g Name ----> use this Name for accessing dont use another case letter word of Name .

# %%
City='Pune'
city

# %%
###########################################################################################################

# %% [markdown]
# # Input function :
#     Synatx :
#         Variable_name = input(promt_message)
#         It is used to take user value .
#
#         Variants of Input function:
#                     1.int(input(promt_message))
#                     2.float(input(promt_message))
#                     3.eval(input(promt_message))

# %%
name = input('Please enter Your full name = ')
print(name)

# %%
type(name)

# %% [markdown]
# ###  1.int(input(promt_message)) :
#     accept only base 10 value .

# %%
number=int(input('Enter number'))

# %%
print(number,type(number))

# %% [markdown]
# ### 2.float(input(promt_message)):
#     it accept int and float value .

# %%
value1=float(input())
print(value1)

# %% [markdown]
# ### 3.eval(input(promt_message)) :
#     It evaluate and execute the variable perticulat data of objects

# %%
a1=eval(input('Data value'))
print(a1,type(a1))

# %%
e

# %% [markdown]
# # 21/06/2026
#
# **Day 4**

# %% [markdown]
# #  Python Comments:
#     Comment in python are Non-executed lines used to annotate and describe the code. They are ignored by the python Interpreter during runtime and are purely for Human readability .
#     Main Purpose of comments are :
#         1. Documentation
#         2. Clarification
#         3. Debugging

# %% [markdown]
# ### Single Line Comments :
#     Comments are denoted using the # 'Hash' symbol .
#     Everything after the # on a line is considered a Comments and is ignored by the Python interpreter.

# %%
 #### Single line comment 
# In this programm we use list object
a=[1,2,3,56,7,8,12,34,23,44,2,4,56,7]
# filter the list element if even then add 2 otherwise in this elemengt add 1
for i in a:
    if i%2==0 :  # in to the even number add 2 
        print(i+2)
    else:
        print(i+1)   # into the odd number add 1

# %% [markdown]
# ### 2. Multiple Line Comments:
#     MultiLine comments using the triple Quotes ('''Multiple lines''' or """Multiple Lines """ ). They often used for Multi-Line explanations or documentation strings{Docstring -->
#     function_name.__doc__ } for function and classes.

# %%
### Multiple line comment 
def even_odd(x):
    """
     ------ This programm for even and odd number manipulation ------
    put the list and then iterate the element on this 
    list and then filter the element .
    if element is even then  add in this element 2 otherwise 
    element is odd then add in this element 1 
    """
    for i in x:
        if i%2==0:
            'in this block even number filter'   # it is called as inline comment 
            print(i+2)
        else:
            'In this block odd number filter '
            print(i+1)

# %%
print(even_odd.__doc__)

# %%
even_odd()

# %%
print()

# %% [markdown]
# ### 3. In-Line Comment :
#     This Comments are used to understanding instrction between the execte the code .

# %%
x=[11,2,2,4,5,]
for i in x:
        if i%2==0:
            'in this block even number filter'   # it is called as inline comment 
            print(i+2)
        else:
            'In this block odd number filter '
            print(i+1)

# %% [markdown]
# # Python Data type:
#     Data types are classification or categories of data that determine the Kind of values that variables can holde .
#     python has several built in Data types are used to represent diff kind of obj and perform the various operation .
# ![image.png](attachment:aad12699-5736-4b1b-83f4-e9ab7bdf7349.png)

# %% [markdown]
# ## 1. text Data type:
#     1. string :
#         It is collection of multiple character enclosed in single {''} or double {""} and triple quotes.

# %%
a='10Shivshayam%^**'   # Single quotes 
print(a)

# %%
print(type(a))

# %%
statement = "It's a laptop"   # Double quotes 
print(statement)

# %%
stmt='''im from Pune    
my name is shiv '''    # Triple quotes
print(stmt)

# %%
stmt="""im from Pune    
my name is shiv """    # Triple quotes
print(stmt)

# %% [markdown]
# # 2. Numerical Data type :
#     2.1 int  :
#         It is Base10 value without the decimal pointer from -ve infinity value to +ve infinity value such as
#         -10,0,10,100
#
#     2.2 float :
#         It is number with  decimal pointer value or in exponential from -ve infinity value to
#         +ve infinity value , such as 3.13 ,1.2,0.23,-0.124,-10,2e3
#     2.3 complex  :
#         Number with a real and imaginary part
#         written as a+bj ,
#                 where a and b are in the float form
#                 and j is represent the imaginary unit 1j = sqrt(-1)

# %%
a=-10
print(a,type(a),sep='\n')

# %%
b=1
print(b,type(b),sep='\n')

# %%
# float :
f=-0.29
print(f,type(f))

# %%
f1=2e34
print(f1,type(f1))

# %%
2.3 complex  :
    Number with a real and imaginary part 
    written as a+bj , 
            where a and b are in the float form 
            and j is represent the imaginary unit 1j = sqrt(-1)

# %%
c=-10-20j
print(c,type(c))

# %%
imag=c.imag
print(imag)

# %%
real=c.real
print(real)

# %% [markdown]
# ### 3.sequence Data type :
#         3.1 List
#         3.2 Tuple
#         3.3 range()

# %% [markdown]
# #### 3.1 list :
#     Ordered collection of items ,mutable (it can be changed) .
#     it collect all element withing the sq bracket with seperating each element by commas.

# %%
l1=[]
print(l1)

# %%
l1=[1,2,12.34,12+23j,-10,-23.34,'Shivsharan']
print(l1)

# %% [markdown]
# #### 3.2 tuple :
#     Ordered collection of 2 or more items ,immutable.
#     it collect all element withing the Round with seperating each element by commas.

# %%
t1=()
print(t1,type(t1))

# %%
t1=(100,)
print(t1,type(t1))

# %% [markdown]
# ### 3.2 range() :
#     It is used to generate a seq of numbers .it is commonly used in Loops and when creating list of number.

# %%
r=range(10)
print(r)

# %%
for i in r:
    print(i)

# %%
list(r)

# %% [markdown]
# ### 4.Mapping Data type :
#     Dict :
#         {key:value}
#         it is key- value pair where each element is unique and associated with a value.

# %% [markdown]
# # 22/06/2026
#
# **Day 5**

# %% [markdown]
# #  Python Comments:
#     Comment in python are Non-executed lines used to annotate and describe the code. They are ignored by the python Interpreter during runtime and are purely for Human readability .
#     Main Purpose of comments are :
#         1. Documentation
#         2. Clarification
#         3. Debugging

# %% [markdown]
# ### Single Line Comments :
#     Comments are denoted using the # 'Hash' symbol .
#     Everything after the # on a line is considered a Comments and is ignored by the Python interpreter.

# %%
 #### Single line comment 
# In this programm we use list object
a=[1,2,3,56,7,8,12,34,23,44,2,4,56,7]
# filter the list element if even then add 2 otherwise in this elemengt add 1
for i in a:
    if i%2==0 :  # in to the even number add 2 
        print(i+2)
    else:
        print(i+1)   # into the odd number add 1

# %% [markdown]
# ### 2. Multiple Line Comments:
#     MultiLine comments using the triple Quotes ('''Multiple lines''' or """Multiple Lines """ ). They often used for Multi-Line explanations or documentation strings{Docstring -->
#     function_name.__doc__ } for function and classes.

# %%
### Multiple line comment 
def even_odd(x):
    """
     ------ This programm for even and odd number manipulation ------
    put the list and then iterate the element on this 
    list and then filter the element .
    if element is even then  add in this element 2 otherwise 
    element is odd then add in this element 1 
    """
    for i in x:
        if i%2==0:
            'in this block even number filter'   # it is called as inline comment 
            print(i+2)
        else:
            'In this block odd number filter '
            print(i+1)

# %%
print(even_odd.__doc__)

# %%
even_odd()

# %%
print()

# %% [markdown]
# ### 3. In-Line Comment :
#     This Comments are used to understanding instrction between the execte the code .

# %%
x=[11,2,2,4,5,]
for i in x:
        if i%2==0:
            'in this block even number filter'   # it is called as inline comment 
            print(i+2)
        else:
            'In this block odd number filter '
            print(i+1)

# %% [markdown]
# # Python Data type:
#     Data types are classification or categories of data that determine the Kind of values that variables can holde .
#     python has several built in Data types are used to represent diff kind of obj and perform the various operation .
# ![image.png](attachment:aad12699-5736-4b1b-83f4-e9ab7bdf7349.png)

# %% [markdown]
# ## 1. text Data type:
#     1. string :
#         It is collection of multiple character enclosed in single {''} or double {""} and triple quotes.

# %%
a='10Shivshayam%^**'   # Single quotes 
print(a)

# %%
print(type(a))

# %%
statement = "It's a laptop"   # Double quotes 
print(statement)

# %%
stmt='''im from Pune    
my name is shiv '''    # Triple quotes
print(stmt)

# %%
stmt="""im from Pune    
my name is shiv """    # Triple quotes
print(stmt)

# %% [markdown]
# # 2. Numerical Data type :
#     2.1 int  :
#         It is Base10 value without the decimal pointer from -ve infinity value to +ve infinity value such as
#         -10,0,10,100
#
#     2.2 float :
#         It is number with  decimal pointer value or in exponential from -ve infinity value to
#         +ve infinity value , such as 3.13 ,1.2,0.23,-0.124,-10,2e3
#     2.3 complex  :
#         Number with a real and imaginary part
#         written as a+bj ,
#                 where a and b are in the float form
#                 and j is represent the imaginary unit 1j = sqrt(-1)

# %%
a=-10
print(a,type(a),sep='\n')

# %%
b=1
print(b,type(b),sep='\n')

# %%
# float :
f=-0.29
print(f,type(f))

# %%
f1=2e34
print(f1,type(f1))

# %%
2.3 complex  :
    Number with a real and imaginary part 
    written as a+bj , 
            where a and b are in the float form 
            and j is represent the imaginary unit 1j = sqrt(-1)

# %%
c=-10-20j
print(c,type(c))

# %%
imag=c.imag
print(imag)

# %%
real=c.real
print(real)

# %% [markdown]
# ### 3.sequence Data type :
#         3.1 List
#         3.2 Tuple
#         3.3 range()

# %% [markdown]
# #### 3.1 list :
#     Ordered collection of items ,mutable (it can be changed) .
#     it collect all element withing the sq bracket with seperating each element by commas.

# %%
l1=[]
print(l1)

# %%
l1=[1,2,12.34,12+23j,-10,-23.34,'Shivsharan']
print(l1)

# %% [markdown]
# #### 3.2 tuple :
#     Ordered collection of 2 or more items ,immutable.
#     it collect all element withing the Round with seperating each element by commas.

# %%
t1=()
print(t1,type(t1))

# %%
t1=(100,)
print(t1,type(t1))

# %%
a=10,20,30  # it is called as packing
print(a,type(a))

# %%
a,b,c=(10,20,30) # It is called as unpaking
print(a)

# %% [markdown]
# ### 3.2 range() :
#     It is used to generate a seq of numbers .it is commonly used in Loops and when creating list of number.

# %%
r=range(10)
print(r)

# %%
for i in r:
    print(i)

# %%
list(r)

# %% [markdown]
# ### 4.Mapping Data type :
#     Dict :
#         {key:value}
#         it is key- value pair where each element is unique and associated with a value.
#         all These pairs all enclosed within the curly brackets....
#
#         key:value
#         enclosed ==> {key:value}
#         key ---> obj ---> string / Text
#         value ---> obj ---> collection obj.

# %%
# 5 Dict :
std_info= {}
print(std_info,type(std_info))
##############################################
std_info= {'Name':['Shivsharan','Adhinath','Simran','Monodnya'],'Department_id' :(1011,1012,1013,1014)}
print(std_info,type(std_info),sep='\n')

# %% [markdown]
# # 5 Unsequence Data type:
#     1.set
#     2.frozenset

# %% [markdown]
# ### 5.1 Set :
#     Unordered Collection of Unique items ,all elemenets are enclosed withing the curly brackets.

# %%
a={10,20,100,200,'Shiv','12Shiv',(1,2,4),100,100}
a

# %% [markdown]
# ### 5.2 Frozenset :
#     It is Immutable version of set .

# %%
a=frozenset({1,2,3,'Shiv',100})
a

# %% [markdown]
# # 6. None Data Type :
#     Represent The Absence of a value or a null value.

# %%
a=None
print(a,type(a))

# %% [markdown]
# # 7. Boolean Data type :
#     Represent Truth Value either True or False .

# %%
A=True 
B=False
print(A,type(A),'\n',B,type(B))

# %% [markdown]
# # 8. Byte and Bytesarray

# %%
a=b'Shiv'
print(a,type(a))

# %%
b=bytearray(10)
print(b,type(b))

# %% [markdown]
# # 23/06/2026
#
# **Day 6**

# %% [markdown]
# # Assignment Operator :
#     This Operators are used to assign values to variables in Python .They allow you to store and Update data in variable .
#         Here are the Commonly used assignment Operator In Python .
#         1. = -->
#                 Assignment --> Assign the value of The right operand to the left operand .
#         2. +=  --> Add and Assign
#                 Adds the right operand to the left operand and assigns the result to the left Operand .
#         3. -= -->  Subtract and assign
#                 subtract the right operand from the left Operand and assigns The result to the left operand .
#         4. *= --> Multiply  and assignment
#         5. /= ---> Division and assign
#         6. //= --> floor division and assign
#         7. %=  --> Reminder and assign

# %%
Number=100
print(f'Assign {Number} Value into the "Number" variable')
Number+=100
print(f'Add and Assign the Right operand into The left operand {Number}')
Number-=100
print(f'Subtract and assign the right operand from the left operand and value is = {Number}')
Number*=2
print(f'Multiply and assign {Number} ')

# %% [markdown]
# # WAP  Simple Shopping Card :
#     product_Price ==> 100
#     Shop_discount ==> 10%
#     Final_product_price=90
#     Shop_GST=5%
#     Final_Product_Value ==?

# %%
# Initial Total price from the SHop
total_price= int (input('Pls enter Product price'))
print(f'Product Price is  {total_price}')
# Apply discount 
discount= float(input('Add Shop Discount'))
print(f'Discount = {discount}')
total_price -=(total_price*(discount/100))
print(f'After the shop discout Product Price is {total_price}')
GST=float(input('Enter GST'))
total_price = total_price +  (total_price* (GST/100))
print(f'final Bill = {total_price}')

# %% [markdown]
# # 3. Logical operator :
#         Logical operator in  python are used to perform logical operations on Boolean Values(True or False).
#     There are Three Main Logical Operators in  Python .
#         3.1 and
#                     This operator return True if Both Operand are true otherwise it return  False
#         3.2 or :
#                     This operator return true if atleast one of The operands is true, otherwise False.
#         3.3 not :   invert the truth Value
#                         true --> false
#                         false --> true

# %% [markdown]
# ### 3.1  and Operator :
#     -------------------truth Table----------------
#     operand1       Operator      operand2      Result
#     True           and           True      ---> True
#     True           and           False     ---> False
#     False          and           True      ---> False
#     False          and           False     ---> False

# %%
a=100
b=200
(a<b) and (type(a)==float)

# %% [markdown]
# ### 3.2  or Operator :
#         atleast one operand is True the return true else false
#     ----------------- Truth Table -----------------
#     Operand1        Operator        Operand2      Result
#     True             or              True          True
#     False            or              True          True
#     True             or              Fasle         True
#     False            or              False         Fasle

# %%
True or False

# %%
False or True or False or False

# %% [markdown]
# ## 3.3 Not :
#     Invert the truth Value
#     It is Unary operator
#     Not True ---> False
#     Not Fale ----> true

# %%
not True

# %%
not False

# %% [markdown]
# # 4. membership operator :
#     In python Membership operators are used to test whether a value or element is present in a seq or container such as string ,list
#     tuple,set ...............
#
#     Python  provide two Membership operator
#         4.1 in
#         4.2 not in

# %%
mail_id='Skunchalwar97@sevenmentor.com'
'12' not in mail_id

# %% [markdown]
# ### 4.1 in operator :
#     The In Operator check is a value exists in a seq or collection. if the value is present ,it return True otherwise it return false.

# %%
fruits=['Apple', 'Banana', 'Orange']
'Apple' in fruits

# %%
'Green apple' in fruits

# %% [markdown]
# ## 4.2 : Not in :
#     the Not in operator check is a value does not exist in a seq or collection.
#     if the value is absent it return True else false

# %%
'Green apple' not in fruits

# %% [markdown]
# # 5. Comparison Operator :
#     It is called as conditional or relational operator .
#     It Return  always boolean value{true/False}
#     it is Binary Operator .
#
#     ## Members of Comparison  Operator
#     (==,<=,>=,<,>,!= ,)
#     == --->  Return True if the Both operand is equal
#     != ---> Not equals to __ it check both operand not equals to each Other.
#     < ----> Less than --> Check left Operand is Less than right Operand
#     > ----> More than ---> check left operand is More than right operand
#     <= ---> less than equals to --> check left operand is less and equal to right operand .
#     >= ---> More than and equal to --> check left operand is more and equal to right operand .

# %%
a=100
b=100.0
c=200
d=20
print(f'{a} and {b} is equals to each other  = {a==b}')
print(f'{a} and {c} is Not equal to each other = {a!=c}')
print(f'{d} is less than {a} = {d<a}')
print(f'{a} is more than {d} = {a>d}')

# %%
a==b

# %% [markdown]
# # 24/06/2026
#
# **Day 7**

# %% [markdown]
# # 6.identity Operator :
#     In Python , Identity operator are used to compare the Memory addresses of two obj to determine whether they refer to the same obj in Memory.
#
#     There are two identity operators in  Python  :
#         6.1 is
#         6.2 is not

# %% [markdown]
# ### 6.1 is operator :
#     The is Operator return True if Both operand refer to the same obj in Memory ,Otherwise it return False

# %%
x='Shivsharan'
y='Shivsharan'
print(id(x),id(y), 'is same')
x is y

# %%
a=100000
b=100000
print(id(a),id(b))

# %%
a=10.0
b=10.0
id(a),id(b)
a is  b

# %% [markdown]
# ### 6.2 is not operator :
#     The is not operator return True if both operands do not refer to the same obj in memory , Otherwise it return False

# %%
a='Hello'
b='hello'
c='Elli'
print(a is not b)
print(a is not c)

# %% [markdown]
# # 7. Bitwise Operator :
#     Bitwise Operator in Python are used to perform operation on Individual bits of integers.These operators are particularly useful when you need to manipulate binary data or perform Low Level Bitwise Operation.
#
#     Here are the Bitwise operators avilable in python.
#     Bitwise and ===>   &
#     Bitwise or ===>    |
#     Bitwise not ===>   ~
#     left Shift ===>    <<
#     Right Shift ===>   >>

# %% [markdown]
# #### 7.1 Bitwise and ===>   & :
#     The Bitwise and Operator compare Two Numbers bit by bit and return 1 where both bits are 1.

# %%
10 & 11

# %%
print(bin(11))
print(bin(13))
print('-'*7)
print(bin(11&13))
print('_'*7)
print(11&13)

# %%
bin(22)

# %%
15 & 17

# %% [markdown]
# ### 7.2 Bitwise OR :
#     ----> |
#     perform a Bitwise or Operator on each pair of corresponding bits in two integers .
#     if at least one of the bits is 1 then return is 1.

# %% [markdown]
# ![image.png](attachment:df4a579e-6a89-4833-9a11-91043af13347.png)

# %%
15 | 17

# %%
print(bin(11))
print(bin(13))
print('-'*7)
print(bin(11|13))
print('_'*7)
print(11|13)

# %% [markdown]
# ### 7.3 Bitwise XOR
#         ---> ^  {Caret} exclusive OR operation.
#         Perform a bitwise exclusive OR (XOR) operation on each pairs of corresponding bits in two integers .
#         If the bits are different the result is 1 otherwise 0.

# %%
print(bin(11))
print(bin(13))
print('-'*7)
print(bin(11^13))
print('_'*7)
print(11^13)

# %% [markdown]
# ### 7.4 Bitwise not :
#     ~ {Twiddle}
#     Flip the Bits of an Int resulting in  the ones complement of the number .
#     Note that the last bit is 1 (sign -) use -ve sign and then flipped  it and add 1 at the first bit and the process.

# %%
~10

# %%
~11

# %%
~13

# %% [markdown]
# ### 7.5 Left Shift :
#     Shifts The bits of an Int to the left by a specified number of Positions. This is equivalent to multiplying the number by 2 to the power of the sift amount.
# ![image.png](attachment:a646d565-69d2-444c-9051-13431d4dd596.png)

# %%
10<<1

# %%
10<<2

# %%
12<<1

# %%
12<<2

# %% [markdown]
# ### 7.5 Right Shift :
#     >>
#     Shifts the B its of an int to the right by a specified number of Position. This is equivalent to dividing the number by 2 to the power of the shift amount and taking the floor value .
# ![image.png](attachment:aa86bdb2-65a5-4cb2-a0af-fb2c8e8a0749.png)

# %%
10>>1

# %%
10>>2

# %% [markdown]
# ![image.png](attachment:8b138f37-30f2-4e44-be0b-fe0e76d94fad.png)
