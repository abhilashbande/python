# %% [markdown]
# # Assignment 3 - Set

# %% [markdown]
# ## Question 1
# **Create a set and print all elements.**

# %%
s={10,20,30,40}
print(s)
# Out:
# {40, 10, 20, 30}

# %% [markdown]
# ## Question 2
# **Create a set from a list containing duplicate values and print the unique elements.**

# %%
lst=[1,2,2,3,4,4,5]
print(set(lst))
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# ## Question 3
# **Add a new element to a set using add().**

# %%
s={1,2,3}
s.add(4)
print(s)
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# ## Question 4
# **Add multiple elements using update().**

# %%
s={1,2}
s.update([2,3,4,5])
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# ## Question 5
# **Remove an element using remove() and observe the error when the element does not exist.**

# %%
s={1,2,3}
s.remove(2)
print(s)
# Out:
# {1, 3}

# %% [markdown]
# ## Question 6
# **Remove an element safely using discard().**

# %%
s={1,2,3}
s.discard(10)
print(s)
# Out:
# {1, 2, 3}

# %% [markdown]
# ## Question 7
# **Remove a random element using pop().**

# %%
s={1,2,3}
print(f'Removed: {s.pop()}')
print(s)
# Out:
# Removed: 1
# {2, 3}

# %% [markdown]
# ## Question 8
# **Clear all elements from a set using clear().**

# %%
s={1,2,3}
s.clear()
print(s)
# Out:
# set()

# %% [markdown]
# ## Question 9
# **Copy one set into another using copy().**

# %%
s1={1,2,3}
s2=s1.copy()
print(s2)
# Out:
# {1, 2, 3}

# %% [markdown]
# ## Question 10
# **Find the union of two sets.**

# %%
a={1,2,3}
b={3,4,5}
print(a.union(b))
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# ## Question 11
# **Find the intersection of two sets.**

# %%
a={1,2,3}
b={2,3,4}
print(a.intersection(b))
# Out:
# {2, 3}

# %% [markdown]
# ## Question 12
# **Find the difference between two sets.**

# %%
a={1,2,3}
b={2,3,4}
print(a.difference(b))
# Out:
# {1}

# %% [markdown]
# ## Question 13
# **Find the symmetric difference between two sets.**

# %%
a={1,2,3}
b={2,3,4}
print(a.symmetric_difference(b))
# Out:
# {1, 4}

# %% [markdown]
# ## Question 14
# **Check whether one set is a subset of another.**

# %%
a={1,2}
b={1,2,3,4}
print(a.issubset(b))
# Out:
# True

# %% [markdown]
# ## Question 15
# **Check whether one set is a superset of another.**

# %%
a={1,2,3,4}
b={1,2}
print(a.issuperset(b))
# Out:
# True

# %% [markdown]
# ## Question 16
# **Check whether two sets are disjoint.**

# %%
a={1,2}
b={3,4}
print(a.isdisjoint(b))
# Out:
# True

# %% [markdown]
# ## Question 17
# **Count the number of unique words in a sentence using a set.**

# %%
text='India is my countr'
print(len(set(text.split())))
# Out:
# 4

# %% [markdown]
# ## Question 18
# **Create a set of squares (1–10) using set comprehension.**

# %%
squares={x*x for x in range(1,11)}
print(squares)

# %% [markdown]
# ## Question 19
# **Remove duplicate names from a list while preserving only unique values (using a set).**

# %%
names=['A','B','A','C','B']
print(list(set(names)))

# %% [markdown]
# ## Question 20
# **Create a frozenset and perform union() and intersection(). Try calling add() and explain the error.**

# %%
fs1=frozenset([1,2,3])
fs2=frozenset([3,4,5])
print(fs1.union(fs2))
print(fs1.intersection(fs2))
# fs1.add(6)
# Error: frozenset is immutable, so add() is not allowed.
